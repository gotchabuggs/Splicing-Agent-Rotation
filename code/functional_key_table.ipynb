# %%
import csv

rows = [
    ["key_id", "biological_function", "category", "feature_name", "description",
     "data_type", "tools_required", "input_data", "output_format",
     "priority_level", "relevant_gene_context", "benchmark_use"],
    
    ["FK001", "Exon skipping", "Splicing Event", "PSI",
     "Percent spliced in for exon inclusion",
     "numeric", "rMATS; SUPPA2", "BAM; GTF", "psi_value",
     "high", "exon-level", "event-level correctness"],
    
    ["FK002", "Alternative 5' splice site", "Splicing Event", "A5SS_usage",
     "Usage proportion of 5’ donor site",
     "numeric", "rMATS", "BAM; GTF", "psi_value",
     "high", "junction-level", "event detection sensitivity"],
    
    ["FK003", "Alternative 3' splice site", "Splicing Event", "A3SS_usage",
     "Usage proportion of 3’ acceptor site",
     "numeric", "rMATS", "BAM; GTF", "psi_value",
     "medium", "junction-level", "recovery of subtle splice shifts"],
    
    ["FK004", "Retained intron", "Splicing Event", "IR_score",
     "Intron retention percentage",
     "numeric", "SUPPA2; IRFinder", "BAM; GTF", "ir_score",
     "high", "intron-level", "event type classification"],
    
    ["FK005", "NMD susceptibility", "NMD", "NMD_flag",
     "Whether isoform likely undergoes nonsense-mediated decay",
     "boolean", "NMDetective; custom python", "transcript sequence", "nmd_flag",
     "high", "transcript", "downstream functional impact"],
    
    ["FK006", "Sequence motif enrichment", "Motif", "MEME_motif_score",
     "Enrichment score for RBP binding motifs",
     "numeric", "MEME Suite; FIMO", "FASTA motif sets", "log_odds_score",
     "medium", "sequence", "regulator prediction"],
    
    ["FK007", "Upstream regulator prediction", "Upstream Gene", "SF_dependency_score",
     "Relative dependency score for splicing factors",
     "numeric", "SpliceAI; regression models", "PSI matrix", "dependency_score",
     "high", "gene-to-gene", "model interpretability"],
    
    ["FK008", "Novel junction discovery", "Event Discovery", "novel_junction_confidence",
     "Confidence score for non-annotated junctions",
     "numeric", "STAR 2-pass", "BAM", "junction_confidence",
     "low", "junction-level", "ability to detect novel events"]
]

# CHANGE THIS PATH TO WHERE YOU WANT THE FILE SAVED
filename = "functional_key_dataset.csv"

# Write UTF-8 explicitly
with open(filename, "w", newline="", encoding="utf-8") as f:
    writer = csv.writer(f)
    writer.writerows(rows)

print(f"Saved UTF-8 CSV → {filename}")
# Out:
# Saved UTF-8 CSV → functional_key_dataset.csv

# %%
print(filename)
# Out:
# functional_keys_template.csv
